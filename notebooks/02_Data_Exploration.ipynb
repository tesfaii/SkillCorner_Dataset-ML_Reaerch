# %%
# Zelle 1 - Drive verbinden
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Zelle 2 - Git konfigurieren
# !git config --global user.name "tesfaii"
# !git config --global user.email "tesfaiamos@gmail.com"
# !git config core.hooksPath /dev/null
# Out:
# fatal: not in a git directory

# %%
# Zelle 3 - Token einrichten
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
# %cd /content/drive/MyDrive/SkillCorner_Dataset-ML_Research
# !git remote set-url origin https://{token}@github.com/tesfaii/SkillCorner_Dataset-ML_Reaerch.git
# Out:
# /content/drive/MyDrive/SkillCorner_Dataset-ML_Research

# %%
# Zelle 1 - Pfad definieren (einmal ändern, überall gültig)
from pathlib import Path



MATCH_ID = "1886347"
BASE_PATH = Path(f"/content/drive/MyDrive/SkillCorner_Dataset-ML_Research/data/matches/{MATCH_ID}")

phases_path   = BASE_PATH / f"{MATCH_ID}_phases_of_play.csv"
dynamic_path  = BASE_PATH / f"{MATCH_ID}_dynamic_events.csv"
tracking_path = BASE_PATH / f"{MATCH_ID}_tracking_extrapolated.jsonl"

# %%
# Zelle 2 - phases_of_play laden und verstehen
import pandas as pd

df_phases = pd.read_csv(phases_path)
df_phases.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 44 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   index                                 454 non-null    int64
#  1   match_id                              454 non-null    int64
#  2   frame_start                           454 non-null    int64
#  3   frame_end                             454 non-null    int64
#  4   time_start                            454 non-null    object
#  5   time_end                              454 non-null    object
#  6   minute_start                          454 non-null    int64
#  7   second_start                          454 non-null    int64
#  8   duration                              454 non-null    float64
#  9   period                                454 non-null    int64
#  10  attacking_side_id                     454 non-null    int64
# ...

# %%
# Zelle 3 - phases_of_play anschauen
df_phases.head(10)
# Out:
#    index  match_id  frame_start  frame_end time_start time_end  minute_start  \
# 0      0   1886347           28         89    00:01.8  00:07.9             0
# 1      1   1886347           89        107    00:07.9  00:09.7             0
# 2      2   1886347          185        232    00:17.5  00:22.2             0
# 3      3   1886347          232        283    00:22.2  00:27.3             0
# 4      4   1886347          283        301    00:27.3  00:29.1             0
# 5      5   1886347          301        351    00:29.1  00:34.1             0
# 6      6   1886347          351        504    00:34.1  00:49.4             0
# 7      7   1886347          504        526    00:49.4  00:51.6             0
# 8      8   1886347          526        530    00:51.6  00:52.0             0
# 9      9   1886347          530        558    00:52.0  00:54.8             0
#
#    second_start  duration  period  ...        third_end  penalty_area_end  \
# ...

# %%
# Zelle 4 - dynamic_events laden und verstehen
df_dynamic = pd.read_csv(dynamic_path)
df_dynamic.info(show_counts=True, verbose=True)

# %%
# Zelle 5 - dynamic_events anschauen
df_dynamic.head(5)

# %%
# Zelle 6 - Tracking: erste Zeile anschauen
import json

with open(tracking_path) as f:
    erste_zeile = json.loads(f.readline())

print(f"Anzahl Schlüssel: {len(erste_zeile.keys())}")
print(erste_zeile.keys())

# %%
# Zelle 7 - Tracking: Struktur jedes Schlüssels verstehen
for key, value in erste_zeile.items():
    print(f"{key}: {type(value).__name__} → {value}")
    print("---")

# %%
# Zelle 8 - Tracking: player_data eines aktiven Frames anschauen
with open(tracking_path) as f:
    for i, line in enumerate(f):
        if i == 200:
            frame_200 = json.loads(line)
            break

print(f"Anzahl Spieler in Frame 200: {len(frame_200['player_data'])}")
print(json.dumps(frame_200["player_data"][0], indent=2))

# %%
# !git add notebooks/02_Data_Exploration.ipynb
# !git commit -m "Data Exploration: phases_of_play, dynamic_events und tracking struktur angeschaut. Kommentare müssen noch gemacht werden"
# !git push

# %%
# !git checkout master
# !git push origin master
