# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/tesfaii/SkillCorner_Dataset-ML_Reaerch.git
# Out:
# /content/drive/MyDrive
# Cloning into 'SkillCorner_Dataset-ML_Reaerch'...
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 409 (delta 100), reused 161 (delta 67), pack-reused 197 (from 1)
# Receiving objects: 100% (409/409), 155.96 MiB | 7.80 MiB/s, done.
# Resolving deltas: 100% (173/173), done.
# Updating files: 100% (84/84), done.
# Filtering content: 100% (10/10), 873.32 MiB | 15.71 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch/.git/hooks/post-checkout': Permission denied

# %%
import os
os.listdir("/content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch/data/matches/1886347/")
# Out:
# ['1886347_dynamic_events.csv',
#  '1886347_match.json',
#  '1886347_phases_of_play.csv',
#  '1886347_tracking_extrapolated.jsonl']

# %%
# !git config --global user.name "tesfaii"
# !git config --global user.email "tesfaiamos@gmail.com"

# %%
# %cd /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch

# !git config core.hooksPath /dev/null
# !git push
# Out:
# /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch
# Everything up-to-date

# %%
from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')

# %cd /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch

# !git remote set-url origin https://{token}@github.com/tesfaii/SkillCorner_Dataset-ML_Reaerch.git
# !git push
# Out:
# /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch
# Everything up-to-date

# %%
# Testdatei erstellen
# !echo "# Test" > /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch/test.md

# Commit und Push
# %cd /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch
# !git add .
# !git commit -m "Test: erste Verbindung erfolgreich"
# !git push
# Out:
# /content/drive/MyDrive/SkillCorner_Dataset-ML_Reaerch
# [master 9bb9bdc] Test: erste Verbindung erfolgreich
#  1 file changed, 1 insertion(+)
#  create mode 100644 test.md
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 286 bytes | 26.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/tesfaii/SkillCorner_Dataset-ML_Reaerch.git
#    6aa02e1..9bb9bdc  master -> master
